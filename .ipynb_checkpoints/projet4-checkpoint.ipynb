# %% [markdown]
# # Projet maison n° 4

# %%
# imports
import requests
import pandas as pd
#from urllib3 import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# **Partie A**
#
# Ecrire une fonction `get_prices_from_url()` qui extrait des informations à partir des 2 pages ci-dessous.
#
# ```python
# URL_PAGE2 = "https://kim.fspot.org/cours/page2.html"
# URL_PAGE3 = "https://kim.fspot.org/cours/page3.html"
# ```
#
# Avec `URL_PAGE2`, la fonction doit retourner :
#
# ```json
# {'Personal': {'price': '$5', 'storage': '1GB', 'databases': 1},
#  'Small Business': {'price': '$25', 'storage': '10GB', 'databases': 5},
#  'Enterprise': {'price': '$45', 'storage': '100GB', 'databases': 25}}
# ```

# %%
# partie A
URL_PAGE2 = "http://kim.fspot.org/cours/page2.html"
URL_PAGE3 = "https://kim.fspot.org/cours/page3.html"

def get_prices_from_url(url):
    soup = BeautifulSoup(requests.get(url).content)
    prices = {}
    p = re.compile('[0-9]+')
    valeur = ''
    for i in range (len(soup.find_all('h2'))):
        row2 = {}
        cle = soup.find_all('h2')[i].text
        z = p.search(soup.find_all(class_='pricing-table-price')[i].text)
        start = int(z.start())
        end = int(z.end())
        dollar = soup.find_all(class_='pricing-table-price')[i].text[start-1:end]
        x = p.search(soup.find_all(class_='pricing-table-list')[i].text)
        storage = soup.find_all(class_='pricing-table-list')[i].text[x.start():x.end()+2]
        databases = soup.find_all(class_='pricing-table-list')[i].find_all('li')[4].text
        r = p.search(databases)
        databases = int(databases[r.start():r.end()])
        row2['price'] = dollar
        row2['storage'] = storage
        row2['databases'] = databases
        prices[cle] = row2
    return prices

# %% [markdown]
# **Partie B**
#
# *L'abus d'alcool est dangereux pour la santé, à consommer avec modération.*
#
# 1) Ecrire une fonction `extract_beer_infos()` qui extrait des informations sur une bière du site de bières *beowulf*.
#
# Exemple d'URL: https://www.beerwulf.com/fr-fr/p/bieres/cuvee-des-trolls.33
#
# La fonction doit retourner :
# ```json
# {'Nom': 'Cuvée des Trolls',
#  'Style': 'Bière Blonde',
#  'Contenu': 25,
#  'Degré d’alcool': 7.0,
#  'Origine': 'Belgique',
#  'Brasseur': 'Brasserie Dubuisson Freres'}
# ```
#
# 2) L'URL ci-après retourne un JSON avec une liste de bières :
#
# ```python
# URL_BEERLIST_FRANCE = "https://www.beerwulf.com/fr-FR/api/search/searchProducts?country=France&container=Bouteille"
# ```
#
# Ecrire une fonction `extract_beer_list_infos(url)` qui prend en argument cet URL et retourne les informations sur une liste de bières du site *beowulf*.
#
# Cette fonction doit retourner la liste des informations obtenues par la fonction précédemment définie `extract_beer_infos()`.
#
# Exemple de retour :
#
# ```json
# [{'Nom':'Desperados','Style':'Lager','Contenu':33,'Degré d’alcool':5.9,'Origine':'France','Brasseur':'Desperados'},
# {'Nom':'La Lager Sans Gluten de Vézelay','Style':'Lager','Contenu':25,'Degré d’alcool':4.0,'Origine':'France','Brasseur':'Brasserie de Vézelay'},
# {'Nom':'Mélusine Bio','Style':'Pale Ale','Contenu': 33,'Degré d’alcool': 5.0,'Origine':'France','Brasseur':'Mélusine'},
# {'Nom':'La Parisienne Le Titi Parisien','Style':'IPA','Contenu':33,'Degré d’alcool':5.5,'Origine':'France','Brasseur': 'Brasserie la Parisienne'},
# {'Nom':'Brasserie De Sutter Brin de Folie','Style':'Bière Blonde','Contenu': 33,'Degré d’alcool':6.5,'Origine':'France','Brasseur':'Brasserie de Sutter'}]
# ```
#
# **Facultatif**
#
# Chercher comment optimiser cette fonction en utilisant `multiprocessing.Pool()` pour paralléliser les accès web.

# %%
soup2
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-add-to-cart="Ajouter" data-available-in-beer-cases="Disponible en Coffrets" data-chargebee-script-required="False" data-chargebee-site-tag="" data-coming-soon="Bientôt disponible" data-create-account-url="/fr-FR/api/account/createAccount" data-create-flexible-subscription="/fr-FR/api/subscription/createFlexibleSubscription" data-datalayer='{"page":{"type":"Product Detail Page","category1":"Bière Blonde","category2":"Torp","language":"fr-FR","country":"FR","currency":"EUR"},"event":"pageView"}' data-dynamic-ui-url="/fr-FR/api/dynamicUi" data-feature-flags="Data-Share-Consent,NewCartDesign,NewFillUpTheBoxLayout,SfmcTransactionEmails" data-is-logged-in-url="/fr-FR/api/account/isLoggedIn" data-is-subscribed-url="/fr-FR/api/subscription/customerHasSubscriptions" data-login-modal-url="fr-FR/loginmodal/loginmodal" data-login-url="/fr-FR/api/account/login" data-original-lang="fr-FR" data-out-of-stock="PRÉVENIR" data-pack-content-api-url="/fr-FR/api/Search/packContent" data-release="197" data-rendered-at="Sat, 01 Oct 2022 14:18:45 GMT" data-subscription-checkout-url="/fr-FR/api/subscription/checkout" data-subscription-discount-percentage="0" data-subscription-plans-url="/fr-FR/api/subscription/plans" lang="fr-FR">
# <head>
# <link crossorigin="" href="https://googleads.g.doubleclick.net" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.google.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.google.nl" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.googleadservices.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://adservice.google.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://tr.snapchat.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.facebook.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://connect.facebook.net" rel="dns-prefetch"/>
# <link crossorigin="" href="https://invitejs.trustpilot.com" rel="dns-prefetch"/>
# <meta charset="utf-8"/>
# <title>St. Feuillien Blond - Fût 2L The SUB  | Achat bière en ligne | Beerwulf</title>
# <!-- Website Meta information -->
# <meta content="https://www.beerwulf.com/fr-fr/p/bieres/st.-feuillien-blond-fut-2l" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@BeerwulfWebshop" name="twitter:site"/>
# <meta content="@BeerwulfWebshop" name="twitter:creator"/>
# <meta content="Une bière puissante et intense, à la robe dorée présentant une épaisse mousse blanche vaporeuse. Les arômes épicés et les notes d'agrumes répondent à l'amertume moyenne du houblon. Une bière au caractère chaleureux, agréable à déguster à tout moment de la journée." name="description"/>
# <meta content="St. Feuillien Blond - Fût 2L The SUB  | Achat bière en ligne" name="title"/>
# <meta content="Une bière puissante et intense, à la robe dorée présentant une épaisse mousse blanche vaporeuse. Les arômes épicés et les notes d'agrumes répondent à l'amertume moyenne du houblon. Une bière au caractère chaleureux, agréable à déguster à tout moment de la journée." property="og:description"/>
# <meta content="Une bière puissante et intense, à la robe dorée présentant une épaisse mousse blanche vaporeuse. Les arômes épicés et les notes d'agrumes répondent à l'amertume moyenne du houblon. Une bière au caractère chaleureux, agréable à déguster à tout moment de la journée." name="twitter:description"/>
# <meta content="product" property="og:type"/>
# <meta content="St. Feuillien Blond - Fût 2L The SUB  | Achat bière en ligne" property="og:title"/>
# <meta content="St. Feuillien Blond - Fût 2L The SUB  | Achat bière en ligne" name="twitter:title"/>
# <meta content="/globalassets/st.-feuillien-blond-torp---2l-keg_1_1.png" property="og:image"/>
# <meta content="/globalassets/st.-feuillien-blond-torp---2l-keg_1_1.png" name="twitter:image"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"NRJS-a90a78f489e3eb14e1b","applicationID":"1590129678","transactionName":"YV1bN0FWXBVRU0BdW1gXbBFaGFQUHVZGG0QZWlAGQVJBSUNEGhlSU01QD19eVwgdUlhbWlIVXxZHGgAK","queueTime":0,"applicationTime":4,"agent":"","atts":""}</script><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1834807891",accountID:"2547547",trustKey:"2092232",xpid:"VgMDVlNXDxABUVhSBgMOUFMJ",licenseKey:"NRJS-a90a78f489e3eb14e1b",applicationID:"1590129678"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(31),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(32),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v]("popstate",function(){i(0,U>1)},N(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.perfor ...
# <link as="font" crossorigin="" href="/static/dist/assets/fonts/Lato/lato-v20-latin-ext_latin-regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/static/dist/assets/fonts/Lato/lato-v20-latin-ext_latin-700.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/static/dist/assets/fonts/Teko/teko-v10-latin-ext_latin_devanagari-700.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/static/dist/assets/fonts/Teko/teko-v10-latin-ext_latin_devanagari-600.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/static/dist/assets/fonts/Teko/teko-v10-latin-ext_latin_devanagari-regular.woff2" rel="preload" type="font/woff2"/>
# <link href="/static/dist/assets/css/app.css?cb=197" rel="stylesheet"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link color="#333333" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="eJrkQkmO9u9SB3OYvMgO" name="cf-2fa-verify"/>
# <link href="https://www.beerwulf.com/de-at/p/biere/st-feuillien-blond-torp-2l-fass" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.beerwulf.com/de-de/p/biere/st-feuillien-blond-2l-fass" hreflang="de-DE" rel="alternate"/>
# <link href="https://www.beerwulf.com/en-gb/p/beers/st-feuillien-blond-2l-keg" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.beerwulf.com/en-nl/p/beers/st-feuillien-blond-2l-keg" hreflang="en-NL" rel="alternate"/>
# <link href="https://www.beerwulf.com/es-es/p/cervezas/st.-feuillien-blond-barril-2L" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.beerwulf.com/fr-be/p/bieres/st-feuillien-blond-2l-fut" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.beerwulf.com/fr-fr/p/bieres/st.-feuillien-blond-fut-2l" hreflang="fr-FR" rel="alternate"/>
# <link href="https://www.beerwulf.com/fr-lu/p/bieres/st.-feuillien-blond-Fut-2L-The-SUB" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.beerwulf.com/it-it/p/birre/st-feuillien-blond-fusto-the-sub" hreflang="it-IT" rel="alternate"/>
# <link href="https://www.beerwulf.com/nl/p/bier/st-feuillien-blond-2l-tapvat" hreflang="nl-NL" rel="alternate"/>
# <link href="https://www.beerwulf.com/nl-be/p/bieren/st-feuillien-blond-2l-tapvat" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.beerwulf.com/fr-fr/p/bieres/st.-feuillien-blond-fut-2l" rel="canonical"/>
# <meta content="index" name="robots"/>
# <!--Load only for production environment -->
# <link crossorigin="" href="//nexus.ensighten.com" rel="preconnect"/>
# <link href="//nexus.ensighten.com" rel="dns-prefetch"/>
# <script defer="" src="//nexus.ensighten.com/heineken/beerwulf-com_-_prod/Bootstrap.js" type="text/javascript"></script>
# <!--Load only pixel if that feature is enabled -->
# <script id="gtm-model">
#             window['noBlocker'] = true;
#             window.dataLayer = window.dataLayer || [];
#         </script>
# <!-- Google Tag Manager -->
# <link crossorigin="" href="//metrics.beerwulf.com" rel="preconnect"/>
# <link href="//metrics.beerwulf.com" rel="dns-prefetch"/>
# <script>
#         (function (w, d, s, l, i) {
#             w[l] = w[l] || []; w[l].push({
#                 'gtm.start':
#                 new Date().getTime(), event: 'gtm.js'
#             }); var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                 '//metrics.beerwulf.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-WXLJX3P');</script>
# <!-- End Google Tag Manager -->
# </head>
# <body class="beervariation">
# <!-- Google DataLayers --><input class="dataLayerDetail" data-datalayer='[{"event":"productDetail","product":{"name":"St. Feuillien Blond - Fût 2L The SUB","id":"St-Feuillien-Blond_1","price":16.490000000,"from-price":null,"category":"Beer/Fûts de bière/Fûts The SUB/Bière Blonde","variant":"St.-Feuillien-Blond-TORP---2L-Keg_1","brand":"ST. FEUILLIEN, St Feuillien","list":"Beer Variation Catalog Entry Summary","position":15,"container":"Torp","stock":"188"}}
# ]' type="hidden"/> <!-- Google Tag Manager -->
# <noscript>
# <iframe height="0" src="//metrics.beerwulf.com/ns.html?id=GTM-WXLJX3P" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager -->
# <header class="header stickit">
# <div class="headercontainer show-search beervariation">
# <div class="top-header">
# <div class="header-row">
# <div class="text-benefit">
# <div>
# <span>
# <a href="/fr-fr/qui-sommes-nous" target="_blank">
#             Tout pour votre bar à domicile
#         </a>
# </span>
# </div><div>
# <span>
# <a href="/fr-fr/qui-sommes-nous" target="_blank">
#             Un assortiment de bières unique
#         </a>
# </span>
# </div><div>
# <span>
# <a href="/fr-fr/livraison-et-retours" target="_blank">
#             Un service hors pair
#         </a>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="header-row-cover">
# <div class="header-row">
# <div class="header-column">
# <a class="logo" href="/fr-fr">logo</a>
# </div>
# <div class="header-column js-search-container">
# <div class="header-search-wrapper">
# <form action="/fr-fr" autocomplete="off" class="header-search icon-search" id="header-search" method="post">
# <input autocomplete="off" autofocus="" class="header-search-input" id="header-search-input" name="searchInput" placeholder="Quelle bière recherchez-vous ? Quel Brasseur ?" type="search"/>
# <input id="type-input" name="type" type="hidden" value="0"/>
# <button class="header-search-submit button centered-content" type="submit">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#magnifier"></use>
# </svg>
# </button>
# </form>
# <div class="search-results-container">
# <h4><span class="js-total-count">0</span> Résultat de la recherche</h4>
# <div class="search-results">
# <div class="single-result js-subscription-kegs-container" data-search-type="subscription-kegs">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#subscription"></use>
# </svg>
# <div>
# <p><span class="js-subscription-kegs-count">0</span> <span class="js-subscription-kegs-title" data-plural-translation="" data-singular-translation=""></span> Trouvés<span class="js-subscription-kegs-discount"> %</span></p><a href="#" id="js-subscription-search-link">Tout voir</a>
# </div>
# </div>
# <div class="single-result js-products-container" data-search-type="products">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#beer"></use>
# </svg>
# <div>
# <p><span class="js-products-count">0</span> <span class="js-products-title" data-plural-translation="Produits" data-singular-translation="Produit"></span> Trouvés</p><a href="#">Tout voir</a>
# </div>
# </div>
# <div class="single-result js-articles-container" data-search-type="articles">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#article"></use>
# </svg>
# <div>
# <p><span class="js-articles-count">0</span> <span class="js-articles-title" data-plural-translation="Articles" data-singular-translation="Article"></span> Trouvés</p><a href="#">Tout voir</a>
# </div>
# </div>
# <div class="single-result js-brewers-container" data-search-type="brewers">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#barrel"></use>
# </svg>
# <div>
# <p><span class="js-brewers-count">0</span> <span class="js-brewers-title" data-plural-translation="Brasseurs" data-singular-translation="Brasseur"></span> Trouvés</p><a href="#">Tout voir</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="header-column">
# <div class="header-shoppingcountry header-icon">
# <div class="show-for-medium">
# <div class="currentselect js-language-select">
# <a class="language-flag js-language-selector" href="/">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#flag-fr"></use>
# </svg>
# </a>
# </div>
# </div>
# <div class="js-toggle-search mobile-search hide-for-medium">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#magnifier"></use>
# </svg>
# </div>
# </div>
# <div class="header-shoppinglist js-header-account header-icon">
# <a class="menu-icon logged-out active" href="/fr-FR/AccountInformation/OrderHistory">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#account_logged_out"></use>
# </svg>
# </a>
# </div>
# <div class="js-header-account header-wishlist header-icon show-for-medium">
# <div data-codes="" id="js-header-shoppinglist">
# <a href="/fr-FR/AccountInformation/Wishlist">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#icon_shoppinglist_header"></use>
# </svg>
# </a>
# </div>
# </div>
# <div class="header-shoppingcart js-shoppingcart" data-ajax-count-url="/fr-FR/api/cart/count/detail" data-ajax-post-url="/fr-FR/api/Cart" data-cart-empty="Votre panier est vide">
# <a class="js-shopping-cart-link shopping-cart-link" href="/fr-fr/panier">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#btn-cart"></use>
# </svg>
# <span class="show-for-sr">Vos bières</span>
# <span class="header-counter hide" id="shoppincarttotal">0</span>
# </a>
# </div>
# </div>
# </div>
# <div class="account-block hide-for-large">
# <a href="/fr-FR/AccountInformation/OrderHistory?returnUrl=%2Ffr-fr%2Fp%2Fbieres%2Fst.-feuillien-blond-fut-2l">
# <svg class="logged-out active" role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#account_logged_out"></use>
# </svg>
# </a>
# </div>
# <div class="header-row navigation-row">
# <div class="header-column secondary-nav">
# <div class="menu-item browse-toggle">
# <h3>Tireuses</h3>
# <div class="navigation-container">
# <nav class="navigation">
# <div class="main-nav-row">
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/the-sub">
# <img alt="Tireuse THE SUB (2L)" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/3.-navigation-icons/homedraught_assortment_appliance_sub_navigation_v2.jpg?rev=1557477805" src="..." title="Tireuse THE SUB (2L)"/>
# </a>
# <h4>Tireuse THE SUB (2L)</h4>
# <p>La pression version design</p>
# <a class="button secondary-button" href="/fr-fr/the-sub">JE DÉCOUVRE</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/tireuse-a-biere-beertender">
# <img alt="Tireuse BeerTender (5L)" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/3.-navigation-icons/homedraught_assortment_appliance_beertender_navigation.jpg?rev=1781438848" src="..." title="Tireuse BeerTender (5L)"/>
# </a>
# <h4>Tireuse BeerTender (5L)</h4>
# <p>La pression grand format</p>
# <a class="button secondary-button" href="/fr-fr/tireuse-a-biere-beertender">JE DÉCOUVRE</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/lots-de-demarrage">
# <img alt="LOTS DE DÉMARRAGE" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/3.-navigation-icons/new-2021-thumbnails/starters_packs_navigation.jpg?rev=1234952330" src="..." title="LOTS DE DÉMARRAGE"/>
# </a>
# <h4>LOTS DE DÉMARRAGE</h4>
# <p>Tout ce dont vous avez besoin</p>
# <a class="button secondary-button" href="/fr-fr/lots-de-demarrage">JE DÉCOUVRE</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/tireuses-a-biere">
# <img alt="Toutes les tireuses" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/3.-navigation-icons/homedraught_assortment_alltaps_navigation_v1.jpg?rev=105151122" src="..." title="Toutes les tireuses"/>
# </a>
# <h4>Toutes les tireuses</h4>
# <p>Le meilleur du service pression à domicile</p>
# <a class="button secondary-button" href="/fr-fr/tireuses-a-biere">J'Y VAIS</a>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div class="menu-item browse-toggle">
# <h3>Fûts et Tubes</h3>
# <div class="navigation-container">
# <nav class="navigation">
# <div class="main-nav-row">
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/c/futsdebiere/futs-the-sub">
# <img alt="Fûts The SUB (2L)" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/3.-navigation-icons/homedraught_assortment_kegs_2l_navigation_v1.jpg?rev=423595266" src="..." title="Fûts The SUB (2L)"/>
# </a>
# <h4>Fûts The SUB (2L)</h4>
# <p>La pression en petit format</p>
# <a class="button secondary-button" href="/fr-fr/c/futsdebiere/futs-the-sub">JE DÉCOUVRE</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/c/futsdebiere/futsdebiere5l">
# <img alt="Fûts (5L)" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/3.-navigation-icons/homedraught_assortment_kegs_5l_navigation.jpg?rev=423595266" src="..." title="Fûts (5L)"/>
# </a>
# <h4>Fûts (5L)</h4>
# <p>Une grande diversité de bières</p>
# <a class="button secondary-button" href="/fr-fr/c/futsdebiere/futsdebiere5l">J'Y VAIS</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/futsdebiere">
# <img alt="Tous les fûts" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/3.-navigation-icons/homedraught_assortment_allkegs_navigation_v1.jpg?rev=105151122" src="..." title="Tous les fûts"/>
# </a>
# <h4>Tous les fûts</h4>
# <p>Les meilleures bières à la pression</p>
# <a class="button secondary-button" href="/fr-fr/futsdebiere">J'Y VAIS</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/tubes-beertender">
# <img alt="TUBES" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/3.-navigation-icons/homedraught_assortment_accessory_tubes_navigation_v2.jpg?rev=2059515126" src="..." title="TUBES"/>
# </a>
# <h4>TUBES</h4>
# <p>Tubes de service pour tireuse BeerTender</p>
# <a class="button secondary-button" href="/fr-fr/tubes-beertender">J'Y VAIS</a>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div class="menu-item browse-toggle">
# <h3>Coffrets de bières</h3>
# <div class="navigation-container">
# <nav class="navigation">
# <div class="main-nav-row">
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/c/coffrets-bieres-mixtes">
# <img alt="Coffrets de bières mixtes" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/3.-navigation-icons/beer_cases_lp_navigation.jpg?rev=592673439" src="..." title="Coffrets de bières mixtes"/>
# </a>
# <h4>Coffrets de bières mixtes</h4>
# <p>Livrés gratuitement chez vous</p>
# <a class="button secondary-button" href="/fr-fr/c/coffrets-bieres-mixtes">J'Y VAIS</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/c/box-promo">
# <img alt="Box Promo" class="lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/navigation/desktop-navigation/featured-packs--gifts/general_navigation_204_affligem_v2.jpg?rev=245146375" src="..." title="Box Promo"/>
# </a>
# <h4>Box Promo</h4>
# <p>Commandez votre bière préférée !</p>
# <a class="button secondary-button" href="/fr-fr/c/box-promo">J'en profite</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/calendrier-avent-biere">
# <img alt="Calendrier de l'Avent" class="lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/landing-pages/advent/advent-lp-2022/advent_lp_navigation.jpg?rev=1008207203" src="..." title="Calendrier de l'Avent"/>
# </a>
# <h4>Calendrier de l'Avent</h4>
# <p>Notre nouveau calendrier est disponible</p>
# <a class="button secondary-button" href="/fr-fr/calendrier-avent-biere">J'ACHÈTE</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/coffrets-de-bieres">
# <img alt="Tous les coffrets" class="lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/navigation/desktop-navigation/featured-packs--gifts/general_navigation_all_packs_de.jpg?rev=2029072732" src="..." title="Tous les coffrets"/>
# </a>
# <h4>Tous les coffrets</h4>
# <p>Découvrez tous nos coffrets</p>
# <a class="button secondary-button" href="/fr-fr/coffrets-de-bieres">JE DÉCOUVRE</a>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div class="menu-item single-link">
# <a href="/fr-fr/cadeaux-biere">IDÉES CADEAUX</a>
# </div>
# <div class="menu-item single-link">
# <a href="/fr-fr/accessoires">ACCESSOIRES</a>
# </div>
# <div class="menu-item browse-toggle">
# <h3>Bières</h3>
# <div class="navigation-container">
# <nav class="navigation">
# <div class="main-nav-row">
# <div class="main-nav-col single-column">
# <div class="beer-content">
# <h4>Découvrez</h4>
# <ul class="no-bullet">
# <li><a href="/fr-fr/c?specialOffer=Nouveaut%c3%a9s">Nouveautés</a></li>
# <li><a href="/fr-fr/promos-biere-tireuse-a-biere">PROMOS</a></li>
# <li><a href="/fr-fr/c/futsthesub">Fûts The SUB</a></li>
# <li><a href="/fr-fr/c?container=F%c3%bbt+de+5L&amp;page=1">Fûts 5L</a></li>
# <li><a href="/fr-fr/c/toutes-les-bieres">Toutes les bières</a></li>
# </ul>
# </div>
# </div>
# <div class="main-nav-col double-column">
# <div class="beer-content">
# <h4>Styles</h4>
# <ul class="no-bullet">
# <li><a href="/fr-fr/c/biereblonde">Bière Blonde</a></li>
# <li><a href="/fr-fr/c/ipa">IPA</a></li>
# <li><a href="/fr-fr/c/lager">Lager</a></li>
# <li><a href="/fr-fr/c/biereblanche">Bière Blanche</a></li>
# <li><a href="/fr-fr/c/bierefruitee">Bière Fruitée</a></li>
# <li><a href="/fr-fr/styles">Tous les styles</a></li>
# </ul>
# </div>
# </div>
# <div class="main-nav-col double-column">
# <div class="beer-content">
# <h4>Pays</h4>
# <ul class="no-bullet">
# <li><a href="/fr-fr/c/biereallemande">Allemagne</a></li>
# <li><a href="/fr-fr/c/bierebelge">Belgique</a></li>
# <li><a href="/fr-fr/c/bierefrancaise">France</a></li>
# <li><a href="/fr-fr/c/biereanglaise">Royaume-Uni</a></li>
# <li><a href="/fr-fr/pays">Tous les pays</a></li>
# </ul>
# </div>
# </div>
# <div class="main-nav-col double-column">
# <div class="beer-content">
# <h4>Brasseries</h4>
# <ul class="no-bullet">
# <li><a href="/fr-fr/p/brasseurs/affligem-brasserie">Affligem</a></li>
# <li><a href="/fr-fr/p/brasseurs/brasserie-desperados">Desperados</a></li>
# <li><a href="/fr-fr/p/brasseurs/brewdog-brasserie">BrewDog</a></li>
# <li><a href="/fr-fr/p/brasseurs/brasserie-du-mont-blanc">Mont-Blanc</a></li>
# <li><a href="/fr-fr/toutes-les-brasseries">Toutes les brasseries</a></li>
# </ul>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div class="menu-item browse-toggle">
# <h3>Découvrir</h3>
# <div class="navigation-container">
# <nav class="navigation">
# <div class="main-nav-row">
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/articles-sur-les-bieres-speciales">
# <img alt="Tous nos articles" class="lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/navigation/desktop-navigation/discover/tapt_navigation_all.jpg?rev=762345998" src="..." title="Tous nos articles"/>
# </a>
# <h4>Tous nos articles</h4>
# <p>Pour tout savoir sur le monde de la bière</p>
# <a class="button secondary-button" href="/fr-fr/articles-sur-les-bieres-speciales">Voir</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/toutes-les-brasseries">
# <img alt="Toutes les brasseries" class="lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/navigation/desktop-navigation/discover/general_pack_2_navigation_brewer_all.jpg?rev=2029072732" src="..." title="Toutes les brasseries"/>
# </a>
# <h4>Toutes les brasseries</h4>
# <p>L'histoire et les secrets des brasseurs et brasseuses</p>
# <a class="button secondary-button" href="/fr-fr/toutes-les-brasseries">J'Y VAIS</a>
# </div>
# </div>
# </div>
# <div class="main-nav-col image-column">
# <div class="beer-content">
# <div class="nav-ad-con">
# <a href="/fr-fr/brasseur-du-mois">
# <img alt="Les brasseries du mois" class="lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/menu-tiles/brewers/stone_general_navigation_botm.jpg?rev=1414959791" src="..." title="Les brasseries du mois"/>
# </a>
# <h4>Les brasseries du mois</h4>
# <p>Portraits vidéos de passionné(e)s</p>
# <a class="button secondary-button" href="/fr-fr/brasseur-du-mois">Découvrir</a>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div class="menu-item single-link">
# <a href="/fr-fr/c?page=1&amp;price=Produits+en+solde">PROMOS</a>
# </div>
# </div>
# </div>
# <div class="header-row add-to-cart-sawtooth-notification js-notification-container" data-close-on-click="true" data-close-on-esc="true" data-reveal="">
# <div class="cart-status-notification-wrapper-sawtooth">
# <div class="status-header">
# <div class="status-title">
# <span class="some">Produit ajouté au panier</span>
# <span class="half">Vous avez rempli un demi-coffret</span>
# <span class="full">Votre coffret est complet</span>
# </div>
# <svg class="close" role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#close"></use>
# </svg>
# </div>
# <div class="cart-status-notication-container">
# <div class="confirmation-text">
# <div class="notification-image"><img alt="" src=""/></div>
# <div class="vertical-center">
# <span class="status-copy added"><b class="js-product-name"></b> Ajouté au panier</span>
# </div>
# <div class="vertical-center">
# <span class="status-copy removed"><b class="js-product-name"></b> a été retiré(e) de votre panier</span>
# </div>
# </div>
# </div>
# <div class="all-free-delivery js-all-free-delivery">
# <span class="check-default active">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#circle-check-default"></use>
# </svg>
# </span>
# <span class="check">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#circle-check"></use>
# </svg>
# </span>
# <span class="free-delivery-text">Chaque colis complet sera livré gratuitement</span>
# </div>
# <div class="cart-status-crate-container js-beer-shippingbox-container">
# <div class="crate-column boxes-to-fill">
# <div class="shipping-info sawtooth">
# <div class="first-box">
# <span class="single-beer">Ajoutez {beersToAddNum} bière de plus à votre coffret pour obtenir la livraison gratuite</span>
# <span class="plural-beer">Ajoutez {beersToAddNum} bières de plus à votre coffret pour obtenir la livraison gratuite</span>
# </div>
# </div>
# <div class="notification-status">
# <div class="fill-box">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#fill-box-black"></use>
# </svg>
# </div>
# <div class="box-status">
# <div class="box-graphic-container js-beers-box-graphic-container">
# </div>
# </div>
# </div>
# </div>
# <div class="crate-column boxes-filled">
# <span class="cart-head-text">Votre livraison sera gratuite !</span>
# </div>
# </div>
# <div class="cart-status-torp-container js-torp-shippingbox-container">
# <div class="crate-column boxes-to-fill">
# <div class="shipping-info sawtooth">
# <div class="first-torp-box">
# <span class="check-default active">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#circle-check-default"></use>
# </svg>
# </span>
# <span class="check">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#circle-check"></use>
# </svg>
# </span>
# <div class="modal-info-text">
# <span class="single-torp">Ajoutez 1 dernier fût The SUB pour obtenir la livraison gratuite</span>
# <span class="plural-torp">Ajoutez {torpsToAddNum} fût(s) The SUB de plus pour obtenir la livraison gratuite </span>
# <span class="add-torps-to-save-some-singular">Ajoutez 1 fût The SUB supplémentaires et ##ÉCONOMISEZ 4€## sur la livraison de ce coffret.</span>
# <span class="add-torps-to-save-some-plural">Ajoutez {torpsToAddNum} fût(s) The SUB supplémentaires et ##ÉCONOMISEZ 4€## sur la livraison de ce coffret.</span>
# <span class="label-you-saved">Vous ## ÉCONOMISEZ 4€ ## sur la livraison pour ce coffret.</span>
# <span class="label-you-saved-full-cost">La livraison ##GRATUITE## a été appliquée à ce coffret.</span>
# </div>
# </div>
# </div>
# <div class="notification-status torp-notification-status">
# <div class="fill-box">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#fill-box-black"></use>
# </svg>
# </div>
# <div class="box-status">
# <div class="box-graphic-container js-torps-box-graphic-container">
# </div>
# </div>
# </div>
# <div class="information torps">
# <div class="info-text">Informations sur la livraison</div>
# <div class="info-icon">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#info"></use>
# </svg>
# </div>
# </div>
# <div class="information-notice" data-product-container="torps">Nous facturons habituellement 8,95 € pour la livraison, mais les commandes de 8 fûts The SUB (ou de multiples de 8) sont livrées GRATUITEMENT. La raison pour laquelle nous livrons des coffrets complets gratuitement est que cela est préférable pour notre environnement.</div>
# </div>
# <div class="crate-column boxes-filled">
# <span class="cart-head-text">Vos fûts The SUB seront livrés gratuitement !</span>
# </div>
# </div>
# <div class="cart-status-keg-container js-keg-shippingbox-container">
# <div class="crate-column boxes-to-fill">
# <div class="shipping-info sawtooth">
# <div class="first-keg-box">
# <span class="check-default active">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#circle-check-default"></use>
# </svg>
# </span>
# <span class="check">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#circle-check"></use>
# </svg>
# </span>
# <div class="modal-info-text">
# <span class="single-keg">Ajoutez 1 fût supplémentaire pour bénéficier de la livraison GRATUITE pour ce coffret.</span>
# <span class="plural-keg">Ajoutez 1 fût supplémentaire et économisez 4€ sur la livraison de ce coffret.</span>
# <span class="add-kegs-to-save-some-singular">Ajoutez 1 fût The SUB supplémentaires et ##ÉCONOMISEZ 4€## sur la livraison de ce coffret.</span>
# <span class="add-kegs-to-save-some-plural">Ajoutez {kegsToAddNum} fût(s) The SUB supplémentaires et ##ÉCONOMISEZ 4€## sur la livraison de ce coffret.</span>
# <span class="label-you-saved">Vous ## ÉCONOMISEZ 4€ ## sur la livraison pour ce coffret.</span>
# <span class="label-you-saved-full-cost">La livraison ##GRATUITE## a été appliquée à ce coffret.</span>
# </div>
# </div>
# </div>
# <div class="notification-status keg-notification-status">
# <div class="fill-box">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#fill-box-black"></use>
# </svg>
# </div>
# <div class="box-status">
# <div class="box-graphic-container js-kegs-box-graphic-container">
# </div>
# </div>
# </div>
# <div class="information kegs">
# <div class="info-text">Informations sur la livraison</div>
# <div class="info-icon">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#info"></use>
# </svg>
# </div>
# </div>
# <div class="information-notice" data-product-container="kegs">Nous facturons habituellement 8,95 € pour la livraison, mais les commandes de 3 fûts de 5L (ou de multiples de 3) sont livrées GRATUITEMENT. La raison pour laquelle nous livrons des coffrets complets gratuitement est que cela est préférable pour notre environnement.</div>
# </div>
# <div class="crate-column boxes-filled">
# <span class="cart-head-text">Vos fûts seront livrés gratuitement !
#
#  </span>
# </div>
# </div>
# <div class="manipulate-cart">
# <div class="manipulate-quantity">
# <div class="add-to-cart-container"><div class="add-to-cart product-is-in-cart showhandlers" data-cy="add-to-cart">
# <button class="modal-minus" data-cy="minus">-</button>
# <input data-sku="" id="modal-input" max="999" maxlength="3" type="tel"/>
# <button class="modal-plus" data-cy="plus" data-textual="Ajouter">+</button>
# <button class="ok">Ok</button></div>
# </div>
# </div>
# <div class="continue-shopping">
# <div class="add-to-cart">
# <button class="more-options">continuer les achats</button>
# <button class="options-to-cart" data-carturl="/fr-fr/panier">Poursuivre vers le panier</button>
# </div>
# </div>
# </div>
# <div class="continue-to-cart-wrapper">
# <button class="continue-to-cart-button" data-carturl="/fr-fr/panier">Poursuivre vers le panier</button>
# </div>
# </div>
# <div class="added-to-shoppinglist-noticiation js-added-to-shoppinglist-noticiation">
# <p class="product-added">
# <span class="js-product-title"></span> a été ajouté(e) à votre liste d'envies
#         </p>
# <p class="product-removed">
# <span class="js-product-title"></span> a été retiré(e) de votre liste d'envies
#         </p>
# </div>
# <div class="hidden">
# <!-- The below spans are hidden, their purpose is to make the localizations accessible in the JS -->
# <span class="label-save">ÉCONOMISEZ 4€</span>
# <span class="label-free">GRATUIT</span>
# </div>
# <div class="cart-status-notification-background"></div>
# </div>
# </div>
# </div>
# <div class="mobile-navigation-row">
# <div class="icon-container">
# <div class="footer-icon js-category-icon-link hamburger-menu-icon" data-category-link="41844665">
# <div class="burger-menu">
# <span></span>
# <span></span>
# <span></span>
# <span></span>
# </div>
# </div>
# <div class="mobile-nav-container">
# <div class="mobile-navigation-menu outer-nav" data-category-menu="41844665">
# <button class="js-nav-close-button close-button" type="button"><span aria-hidden="true">×</span></button>
# <h4 class="section-title">Menu</h4>
# <ul class="no-bullet">
# <li class="category-link js-category-link">
#     Tireuses
#     <div class="mobile-navigation-menu inner-nav">
# <h4 class="section-title inner-section-title js-close-inner-menu">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#arrow-left"></use>
# </svg>
#             Tireuses
#         </h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/the-sub">Tireuse The SUB (2L)</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/tireuse-a-biere-beertender">Tireuse BeerTender (5L)</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/lots-de-demarrage">Lots de démarrage</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/tireuses-a-biere">Toutes les tireuses</a></li>
# </ul>
# </div>
# </li>
# <li class="category-link js-category-link">
#     Fûts et Tubes
#     <div class="mobile-navigation-menu inner-nav">
# <h4 class="section-title inner-section-title js-close-inner-menu">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#arrow-left"></use>
# </svg>
#             Fûts et Tubes
#         </h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/futsdebiere/futs-the-sub">Fûts The SUB (2L)</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/futsdebiere/futsdebiere5l">Fûts (5L)</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/futsdebiere">Tous les fûts</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/tubes-beertender">Tubes</a></li>
# </ul>
# </div>
# </li>
# <li class="category-link js-category-link">
#     Coffrets de bières
#     <div class="mobile-navigation-menu inner-nav">
# <h4 class="section-title inner-section-title js-close-inner-menu">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#arrow-left"></use>
# </svg>
#             Coffrets de bières
#         </h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/coffrets-bieres-mixtes">Coffrets de bières mixtes</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/box-promo">Box Promo</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/calendrier-avent-biere">Calendrier de l'Avent 2022</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/coffrets-de-bieres">Tous nos coffrets</a></li>
# </ul>
# </div>
# </li>
# <li class="category-link js-category-link">
#     Offrir un cadeau
#     <div class="mobile-navigation-menu inner-nav">
# <h4 class="section-title inner-section-title js-close-inner-menu">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#arrow-left"></use>
# </svg>
#             Offrir un cadeau
#         </h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/cadeaux-biere">Idées Cadeaux</a></li>
# </ul>
# </div>
# </li>
# <li class="category-link js-category-link">
#     Nos accessoires
#     <div class="mobile-navigation-menu inner-nav">
# <h4 class="section-title inner-section-title js-close-inner-menu">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#arrow-left"></use>
# </svg>
#             Nos accessoires
#         </h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/accessoires">Verres à bière</a></li>
# </ul>
# </div>
# </li>
# <li class="category-link js-category-link">
#     Découvrez nos bières
#     <div class="mobile-navigation-menu inner-nav">
# <h4 class="section-title inner-section-title js-close-inner-menu">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#arrow-left"></use>
# </svg>
#             Découvrez nos bières
#         </h4>
# <ul class="no-bullet">
# <li class="category-link js-category-link">
#     Styles
#     <div class="mobile-navigation-menu inner-nav">
# <h4 class="section-title inner-section-title js-close-inner-menu">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#arrow-left"></use>
# </svg>
#             Styles
#         </h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/biereblonde">Bière Blonde</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/ipa">IPA</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/lager">Lager</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/biereblanche">Bière Blanche</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/bierefruitee">Bière Fruitée</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/styles">Tous les styles</a></li>
# </ul>
# </div>
# </li>
# <li class="category-link js-category-link">
#     Pays
#     <div class="mobile-navigation-menu inner-nav">
# <h4 class="section-title inner-section-title js-close-inner-menu">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#arrow-left"></use>
# </svg>
#             Pays
#         </h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/biereallemande">Allemagne</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/bierebelge">Belgique</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/bierefrancaise">France</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/biereanglaise">Royaume-Uni</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/pays">Tous les pays</a></li>
# </ul>
# </div>
# </li>
# <li class="category-link js-category-link">
#     Brasseries
#     <div class="mobile-navigation-menu inner-nav">
# <h4 class="section-title inner-section-title js-close-inner-menu">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#arrow-left"></use>
# </svg>
#             Brasseries
#         </h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/p/brasseurs/affligem-brasserie">Affligem</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/p/brasseurs/brasserie-desperados">Desperados</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/p/brasseurs/brewdog-brasserie">Brewdog</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/p/brasseurs/brasserie-du-mont-blanc">Mont-Blanc</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/toutes-les-brasseries">Toutes les brasseries</a></li>
# </ul>
# </div>
# </li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c?specialOffer=Nouveaut%c3%a9s">Nouveautés</a></li>
# </ul>
# </div>
# </li>
# <li class="category-link js-category-link">
#     Découvrir la bière
#     <div class="mobile-navigation-menu inner-nav">
# <h4 class="section-title inner-section-title js-close-inner-menu">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#arrow-left"></use>
# </svg>
#             Découvrir la bière
#         </h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/articles-sur-les-bieres-speciales">Le Blog</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/toutes-les-brasseries">Les brasseurs et brasseuses</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/brasseur-du-mois">Les brasseries du mois</a></li>
# </ul>
# </div>
# </li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/promos-biere-tireuse-a-biere">PROMOS</a></li>
# <li class="direct-link"><a href="https://frbeerwulf.zendesk.com/hc/fr-fr">Questions fréquentes</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-icon js-category-icon-link" data-category-link="4112732">
# <div class="menu-icon active-icon" style="background-image:url('/globalassets/1.-everyday-assets/1.1-navigation-icons/beer-tap.svg?rev=1062082360')"></div>
# <div class="menu-icon inactive-icon" style="background-image:url('/globalassets/1.-everyday-assets/1.1-navigation-icons/beer-tap.svg?rev=1062082360')"></div>
#                         Tireuses
#                     </div>
# <div class="mobile-nav-container">
# <div class="mobile-navigation-menu outer-nav" data-category-menu="4112732">
# <button class="js-nav-close-button close-button" type="button"><span aria-hidden="true">×</span></button>
# <h4 class="section-title">Tireuses</h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/the-sub">The SUB (2L)</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/tireuse-a-biere-beertender">Beertender (5L)</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/lots-de-demarrage">Lots de démarrage</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/tireuses-a-biere">Toutes les tireuses</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-icon js-category-icon-link" data-category-link="62566003">
# <div class="menu-icon active-icon" style="background-image:url('/globalassets/1.-everyday-assets/1.1-navigation-icons/kegs.svg?rev=932162488')"></div>
# <div class="menu-icon inactive-icon" style="background-image:url('/globalassets/1.-everyday-assets/1.1-navigation-icons/kegs.svg?rev=932162488')"></div>
#                         Fûts et Tubes
#                     </div>
# <div class="mobile-nav-container">
# <div class="mobile-navigation-menu outer-nav" data-category-menu="62566003">
# <button class="js-nav-close-button close-button" type="button"><span aria-hidden="true">×</span></button>
# <h4 class="section-title">Fûts et Tubes</h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/futsdebiere/futs-the-sub">Fûts The SUB (2L)</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/futsdebiere/futsdebiere5l">Fûts (5L)</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/futsdebiere">Tous les fûts</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/tubes-beertender">Tubes</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-icon js-category-icon-link" data-category-link="45145043">
# <div class="menu-icon active-icon" style="background-image:url('/globalassets/1.-everyday-assets/1.1-navigation-icons/cases.svg?rev=1325261897')"></div>
# <div class="menu-icon inactive-icon" style="background-image:url('/globalassets/1.-everyday-assets/1.1-navigation-icons/cases.svg?rev=1325261897')"></div>
#                         Coffrets de bières
#                     </div>
# <div class="mobile-nav-container">
# <div class="mobile-navigation-menu outer-nav" data-category-menu="45145043">
# <button class="js-nav-close-button close-button" type="button"><span aria-hidden="true">×</span></button>
# <h4 class="section-title">Coffrets de bières</h4>
# <ul class="no-bullet">
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/coffrets-bieres-mixtes">Coffrets de bières mixtes</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/c/box-promo">Box Promo</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/calendrier-avent-biere">Calendrier de l'Avent 2022</a></li>
# <li class="direct-link js-direct-link"><a href="/fr-fr/coffrets-de-bieres">Tous les coffrets</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-icon js-direct-icon-link">
# <a href="/fr-fr/accessoires">
# ...
# <div class="fixed-content-container">
# <div class="icon-row-container">
# <div class="row grey-bg">
# <div class="small-12 columns">
# <div class="icon-row"><div class="icon-container">
# <div class="image-container">
# <img alt="15 JOURS DE CONSERVATION" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/icons/calendar15.png" src="..." title="15 JOURS DE CONSERVATION"/>
# </div>
# <div class="icon-copy">
# <h3>15 JOURS DE CONSERVATION</h3>
# <span>Prenez le temps de la dégustation jusqu'à 15 jours après ouverture</span>
# </div>
# </div><div class="icon-container">
# <div class="image-container">
# <img alt="COMPATIBLE AVEC The SUB" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/icons/draught-machine.png" src="..." title="COMPATIBLE AVEC The SUB"/>
# </div>
# <div class="icon-copy">
# <h3>COMPATIBLE AVEC The SUB</h3>
# <span>Utilisez ces fûts de 2L avec la machine SUB</span>
# </div>
# </div><div class="icon-container">
# <div class="image-container">
# <img alt="BIÈRE FRAÎCHEMENT SERVIE" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/icons/cold.png" src="..." title="BIÈRE FRAÎCHEMENT SERVIE"/>
# </div>
# <div class="icon-copy">
# <h3>BIÈRE FRAÎCHEMENT SERVIE</h3>
# <span>Pour une température idéale, n’oubliez pas de refroidir le fût avant usage.</span>
# </div>
# </div><div class="icon-container">
# <div class="image-container">
# <img alt="COMMENT CONSERVER LE FÛT ?" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/icons/storage.png" src="..." title="COMMENT CONSERVER LE FÛT ?"/>
# </div>
# <div class="icon-copy">
# <h3>COMMENT CONSERVER LE FÛT ?</h3>
# <span>Conservez les fûts dans un endroit sec à l'abri de la lumière et de la chaleur</span>
# </div>
# </div></div>
# </div>
# </div>
# </div>
# <div class="row accordrion-row">
# <div class="small-12 columns">
# <div class="component-page-rows">
# <div class="single-content-row">
# <div class="details-accordion">
# <div class="accordion-element">
# <div class="accordion-header">
# <h4>Détails</h4>
# </div>
# <div class="accordion-body">
# <div class="row">
# <div class="small-12 medium-6 columns">
# <table class="specs-table">
# <tbody>
# <tr>
# <td class="header">Style</td>
# <td>Bière Blonde</td>
# </tr>
# <tr>
# <td class="header">Contenu</td>
# <td>2 Litres</td>
# </tr>
# <tr>
# <td class="header">Degré d’alcool</td>
# <td>7,0%</td>
# </tr>
# <tr>
# <td class="header">Malt</td>
# <td>
# <ul class="no-bullet">
# <li class="small-12">
#                                                                     Malt d'orge
#                                                                 </li>
# </ul>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="small-12 medium-6 columns">
# <table class="specs-table">
# <tbody>
# <tr>
# <td class="header">Origine</td>
# <td>
#                                                     Belgique
#                                                 </td>
# </tr>
# <tr>
# <td class="header">Brasseur</td>
# <td>
# <a href="/fr-fr/p/brasseurs/st-feuillien">St. Feuillien</a>
# </td>
# </tr>
# <tr>
# <td class="header">Allergènes</td>
# <td>
# <ul class="no-bullet">
# <li class="small-12">
#                                                                     Malt d'orge
#                                                                 </li>
# </ul>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="accordion-element">
# <div class="accordion-header">
# <h4>Conseil pour servir</h4>
# </div>
# <div class="accordion-body">
# <div class="row">
# <ul class="serving no-bullet">
# <li>
# <div class="serving-icons">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#glass-tulip"></use>
# </svg>
# </div>
# <div>
# <h5>Verre</h5>
# <p>Tulip</p>
# </div>
# </li>
# <li>
# <div class="serving-icons">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#foodpairing"></use>
# </svg>
# </div>
# <div>
# <h5>Délicieux avec ? </h5>
# <p>Poissons gras, Fromages crémeux</p>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="accordion-element">
# <div class="accordion-header">
# <h4>Goût</h4>
# </div>
# <div class="accordion-body">
# <div class="row">
# <div class="tasting small-12 columns">
# <h5>Nuances de goût</h5>
# <div class="taste-tables">
# <div><dt>
# <span aria-haspopup="true" class="has-tip top" data-disable-hover="false" data-h-offset="5" data-tooltip="" data-v-offset="5" title="L’intensité du goût, sur une échelle de 1 à 5.">
#         Intensité
#     </span>
# </dt>
# <dd>
# <div class="dots" data-percent="60"></div>
# </dd></div>
# <div><dt>
# <span aria-haspopup="true" class="has-tip top" data-disable-hover="false" data-h-offset="5" data-tooltip="" data-v-offset="5" title="La longueur du goût représente l’arrière-goût d’une bière.">
#         Longueur
#     </span>
# </dt>
# <dd>
# <div class="dots" data-percent="60"></div>
# </dd></div>
# <div><dt>
# Douceur
# </dt>
# <dd>
# <div class="dots" data-percent="60"></div>
# </dd></div>
# <div><dt>
# Acidité
# </dt>
# <dd>
# <div class="dots" data-percent="20"></div>
# </dd></div>
# <div><dt>
# Amertume
# </dt>
# <dd>
# <div class="dots" data-percent="40"></div>
# </dd></div>
# <div><dt>
# <span aria-haspopup="true" class="has-tip top" data-disable-hover="false" data-h-offset="5" data-tooltip="" data-v-offset="5" title="Umami est un mot d’origine japonaise qui signifie « délicieux » ou « sain ».">
#         Umami
#     </span>
# </dt>
# <dd>
# <div class="dots" data-percent="0"></div>
# </dd></div>
# <div><dt>
# <span aria-haspopup="true" class="has-tip top" data-disable-hover="false" data-h-offset="5" data-tooltip="" data-v-offset="5" title="IBU signifie International Bitterness Unit, une échelle qui indique l’amertume d’une bière.">
#         IBU
#     </span>
# </dt>
# <dd>
# <strong>-</strong> / 120
# </dd></div>
# </div>
# </div>
# <div class="small-12 columns">
# <h5>Couleur de la bière (EBC)</h5>
# <div class="ebc">
# <div></div>
# <div class="active">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#check"></use>
# </svg>
# </div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# </div>
# </div>
# <div class="small-12 columns">
# <h5>Caractéristiques</h5>
# <ul class="tasting-icons-container no-bullet">
# <li>
# <div class="tasting-icons">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#taste-fruityfloral"></use>
# </svg>
# </div>
# <p>
# <strong>Floral &amp; Fruity</strong><br/>
# </p>
# </li>
# <li>
# <div class="tasting-icons">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#taste-savourystrong "></use>
# </svg>
# </div>
# <p>
# <strong>Strong &amp; Savory</strong><br/>
# </p>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="accordion-element">
# <div class="accordion-header">
# <h4>Brasseur</h4>
# </div>
# <div class="accordion-body brewer-accordion">
# <div class="row">
# <div class="small-12 columns">
# <img alt="St Feuillien" src="/fr-fr/SysSiteAssets/brewer-logos/belgium/st_feuillien_logo.png" title="St Feuillien"/>
# <h5>St Feuillien</h5>
# <p>
#                                                 Stéphanie Friart a fondé la brasserie St-Feuillien en 1873 en Belgique. Il y a eu, depuis, cinq génération de brasseurs ! St-Feuillien c’est aujourd’hui un large éventail de bières de grande qualité dont la St-Feuillien Grand Cru de nombreuses fois médaillées. La brasserie propose des bières classiques belges &amp; des bières plus innovantes, et même une bière biologique sans gluten : la Grisette Blonde.
#
#                                             </p>
# <a class="button forward white" href="/fr-fr/p/brasseurs/st-feuillien">En savoir plus sur St-Feuillien</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="application/ld+json">
#     {
#   "@context": "http://schema.org/",
#   "@type": "Product",
#   "name": "St. Feuillien Blond - Fût 2L The SUB",
#   "image": "https://www.beerwulf.com/globalassets/st.-feuillien-blond-torp---2l-keg_1_1.png",
#   "description": "Une bière puissante et intense, à la robe dorée présentant une épaisse mousse blanche vaporeuse. Les arômes épicés et les notes d'agrumes répondent à l'amertume moyenne du houblon. Une bière au caractère chaleureux, agréable à déguster à tout moment de la journée.",
#   "gtin13": "8719638659239",
#   "brand": {
#     "@type": "Thing",
#     "name": "St Feuillien"
#   },
#   "aggregateRating": {
#     "@type": "AggregateRating",
#     "ratingValue": "4",
#     "reviewCount": "15"
#   },
#   "offers": {
#     "@type": "Offer",
#     "priceCurrency": "EUR",
#     "itemCondition": "http://schema.org/NewCondition",
#     "price": "16.49",
#     "availability": "http://schema.org/InStock"
#   }
# }
# </script>
# </div>
# <div aria-labelledby="modalmessage" class="reveal tiny" data-reveal="" id="modalmessage">
# <p id="modalmessagecontent"></p>
# <button aria-label="Close Accessible Modal" class="close-button" data-close="" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="reveal" id="shoppingcart"></div>
# <div aria-labelledby="pack-preview-modal-header" class="small reveal pack-preview-modal" data-reveal="" id="pack-preview-modal">
# <div class="row">
# <div class="small-12 columns">
# <button aria-label="Close pack preview" class="close-button" data-close="" type="button">
# <span aria-hidden="true">×</span>
# </button>
# <h2 id="pack-preview-modal-header"></h2>
# <h4 id="pack-preview-subtitle"></h4>
# <div class="pack-preview-modal-body" id="pack-preview-modal-body"></div>
# </div>
# </div>
# </div>
# <div aria-labelledby="modalmessage" class="reveal cookie-modal-container fr-FR" data-close-on-click="false" data-close-on-esc="false" data-reveal="" id="cookiemessage">
# <div class="cookie-logo">
# <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#beerwulf-text-logo-inverted"></use>
# </svg>
# </div>
# <div class="cookie-msg-container">
# <div id="agreeAndEighteenContainer">
# <h3>Avez-vous plus de 18 ans?
# </h3>
# <div><p style="line-height: 1.2;">Vous ne pouvez acheter de la bière que si vous avez 18 ans ou plus. La vente d'alcool est interdite aux mineurs.</p></div>
# <div class="row splash-cta">
# <div class="small-6 text-right">
# <a class="primary button" href="#" id="eighteenTrigger">Oui</a>
# </div>
# <div class="small-6 text-left">
# <a class="primaryblack button" href="/link/b0a69ed0559042e8a506aceaf157ac46.aspx?epslanguage=fr-FR">Non</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footerbar-container">
# <div class="footerbar-row">
# <div class="newsletter-subscription">
# <div data-ajax-post-url="/fr-FR/api/CustomerMarketingData/subscribe" id="subscribenewsletter">
# <div>
# <h5>Inscrivez-vous à notre Newsletter</h5>
# <span>Et recevez en exclusivité nos offres, ventes privées et nouveautés !</span>
# </div>
# <form>
# <input autocomplete="email" data-val="true" id="email" pattern="^[a-zA-Z0-9_]+([_%+a-zA-Z0-9-]|[.](?!\.))*@[a-zA-Z0-9_]+(([_%+-]|[.](?!\.))*[a-zA-Z0-9])*?\.[a-zA-Z]{2,}$" placeholder="Entrez votre adresse email" required="" type="email"/>
# <input class="button" type="submit" value="Ok"/>
# </form>
# </div>
# <p class="thankyou">Merci pour votre inscription</p>
# </div>
# </div>
# </div>
# <footer>
# <div class="footer">
# <div class="row footer-menu">
# <div class="footer-column columns accordian-link">
# <h4 class="footer-heading">Aide</h4>
# <div class="footer-content">
# <ul class="footer-list">
# <li>
# <a href="/fr-fr/livraison-et-retours">Livraisons &amp; retours</a>
# </li>
# <li>
# <a href="https://frbeerwulf.zendesk.com/hc/fr-fr">Questions fréquentes</a>
# </li>
# <li>
# <address class="footer-address">
# <br/>
# <br/>
# <a href="tel:"></a>
# </address>
# </li>
# <li>
# <address class="footer-address">
#     Service de rappel téléphonique :
#     <br/>
#     lun - ven / 10:00 - 17:00
#     <br/>
# <a href="tel:+33 805 089 853">+33 805 089 853</a>
# </address>
# </li>
# <li>
# <a class="button primary zendesk-activator-button js-zendesk-activator-button" data-title="Contact" href="#">
#         Contact
#     </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="footer-column columns accordian-link">
# <h4 class="footer-heading">À propos</h4>
# <div class="footer-content">
# <ul class="footer-list">
# <li>
# <a href="/fr-fr/qui-sommes-nous">Qui sommes-nous ?</a>
# </li>
# <li>
# <a href="/fr-fr/ce-que-nos-clients-disent-de-nous">Avis &amp; expériences clients</a>
# </li>
# <li>
# <a href="https://beerwulf.homerun.co/">Recrutement</a>
# </li>
# <li>
# <a href="/fr-fr/la-durabilite-chez-beerwulf">La durabilité chez Beerwulf</a>
# </li>
# <li>
# <a href="https://www.alcool-info-service.fr/">Alcool-info-service</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="footer-column columns accordian-link">
# <h4 class="footer-heading">Pays</h4>
# <div class="footer-content">
# <ul class="footer-list">
# <li class="js-language-select">
# <a class="footer-language-flag js-language-selector" href="/">
#         Vous êtes sur le site
#         <svg role="img">
# <use xlink:href="/static/dist/assets/img/svg.svg#flag-fr"></use>
# </svg>
#         Changer
#     </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="footer-column columns">
# <h4 class="footer-heading">Suivez-nous</h4>
# <div class="footer-content">
# <ul class="footer-list">
# <li class="social-media">
# <a href="https://www.facebook.com/BeerwulfWebshop/" target="_blank">
# <img alt="Social media icon" class="social-media-item lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/navigation/footer-navigation/follow-us/icon-facebook.svg?rev=1398306123" src="..." title="Social media icon"/>
# </a>
# </li>
# <li class="social-media">
# <a href="https://www.instagram.com/beerwulfwebshop/" target="_blank">
# <img alt="Social media icon" class="social-media-item lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/navigation/footer-navigation/follow-us/icon-instagram.svg?rev=257255883" src="..." title="Social media icon"/>
# </a>
# </li>
# <li class="social-media">
# <a href="https://twitter.com/BeerwulfWebshop" target="_blank">
# <img alt="Social media icon" class="social-media-item lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/navigation/footer-navigation/follow-us/icon-twitter.svg?rev=207593035" src="..." title="Social media icon"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="row payment-logos">
# <div class="footer-column columns">
# <h4 class="footer-heading">Moyens de paiement - Livraisons</h4>
# <a href="/fr-fr/moyens-paiement-securises" target="_blank">
# <img alt="" class="lazy-image" data-src="https://www.beerwulf.com/globalassets/au-fr-esp-uk-it-mar2020.png?rev=334924766" src="..." title=""/>
# </a>
# </div>
# </div>
# <div class="row">
# <div class="notice-text">
# <p>Beerwulf fait partie d’HEINEKEN</p>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="columns text-center">
# <div class="lower-footerbar-logos">
# <a class="footerbar-logo" href="https://www.ecommercetrustmark.eu/" rel="nofollow" target="_blank">
# <img alt="" class="lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/navigation/footer-navigation/underfooteritems/trust_ecommerce_logo.svg?rev=61156986" src="..." title=""/>
# </a>
# <a class="footerbar-logo" href="https://solidarites-sante.gouv.fr/prevention-en-sante/addictions/article/alcool-cadre-legal" rel="nofollow" target="_blank">
# <img alt="" class="lazy-image" data-src="https://www.beerwulf.com/fr-fr/SysSiteAssets/homepage-header--theme-tiles/navigation/footer-navigation/underfooteritems/pregnancylogonoalcohol.jpeg?rev=1816339845" src="..." title=""/>
# </a>
# </div>
# <div class="footer-smallprint">
# <a href="https://www.alcool-info-service.fr/" target="_blank">L’abus d’alcool est dangereux pour la santé, à consommer avec modération</a>
# <a href="/fr-fr/conditions-generales" target="_blank">Conditions générales</a>
# <a href="/fr-fr/politique-de-confidentialite-et-cookies" target="_blank">Politique de Confidentialité</a>
# <a href="/fr-fr/politique-en-matiere-de-cookies" target="_blank">Cookies</a>
# <a href="https://www.beerwulf.com/trigger-cookie-tool" target="_blank">Configuration des cookies</a>
# <span class="js-language-select">
# <a href="/">Français (FR)</a>
# </span>
# </div>
# </div>
# </div>
# </footer>
# <input data-getcartcount-url="/fr-FR/api/Cart/Count" id="refreshed" type="hidden" value="no"/>
# <script src="/static/dist/assets/js/BeerWulf.js?cb=197"></script>
# <!--Load only for production environment -->
# <script>
#             addABTastyScript();
#         </script>
# </body>
# </html>

# %%
soup2.find_all('td', attrs={'class':"header"})
# Out:
# [<td class="header">Style</td>,
#  <td class="header">Contenu</td>,
#  <td class="header">Degré d’alcool</td>,
#  <td class="header">Malt</td>,
#  <td class="header">Origine</td>,
#  <td class="header">Brasseur</td>,
#  <td class="header">Allergènes</td>]

# %%
r = requests.get(URL_BEERLIST_FRANCE)
body = r.json()
body['items']
beer_pages = []
for i in range(len(body['items'])):
    print(body["items"][i]['contentReference'])
     #beer_pages.append(URL_BEERLIST_FRANCE+)
# Out:
# /fr-fr/p/bieres/la-cristal-ipa-du-mont-blanc.33
# /fr-fr/p/bieres/ninkasi-ambree-.33
# /fr-fr/p/bieres/desperados.33
# /fr-fr/p/bieres/pietra.33

# %%
body = r.json()
body['items']
# Out:
# [{'title': 'La Cristal IPA du Mont Blanc',
#   'description': '',
#   'images': [{'image': '/globalassets/la-cristal-ipa-du-mont-blanc.33_1_1.png',
#     'badge': {'url': '/globalassets/catalog/beerwulf/beers/awards/wba-france-gold-2018.png',
#      'alt': 'WBA France Gold 2018',
#      'title': 'WBA France Gold 2018'},
#     'name': None}],
#   'contentReference': '/fr-fr/p/bieres/la-cristal-ipa-du-mont-blanc.33',
#   'redirectedUrl': None,
#   'details': 'IPA | 4,7% | 33 cl',
#   'worksWithLabel': None,
#   'productIcon': None,
#   'searchItemType': 0,
#   'promotedPages': [],
#   'code': 'La-Cristal-IPA-du-Mont-Blanc.33_1',
#   'inStock': True,
#   'isComingSoon': False,
#   'isBottleOrCan': True,
#   'inReserveStock': True,
#   'style': 'IPA',
#   'alcoholPercentage': 4.7,
#   'volume': 33.0,
#   'displayInformationPrice': {'currency': '€',
#    'price': '2,89 €',
#    'filterPrice': 2.89,
#    'fromPrice': None,
#    'discountPrice': None,
#    'discountPercentage': '0',
#    'valueIndicator': None,
#    'pricePerLiter': '8,76 €',
#    'depositMoney': None,
#    'displayDepositMoneyAndPricePerLiter': False,
#    'hasDiscount': False,
#    'vatPercentage': '20%',
#    'saleType': 'Regular',
#    'preorderAvailability': None},
#   'amountInCart': 0,
#   'isInWishlist': False,
#   'containerType': 'Bottle',
#   'includesFreeItem': False,
#   'freeItemIcon': None,
#   'saleType': None,
#   'sellerId': None,
#   'sellerName': None,
#   'sellerFriendlyUrl': None},
#  {'title': 'Ninkasi Pale Ale',
#   'description': '',
#   'images': [{'image': '/globalassets/ninkasi-ambree.33_1_0.png',
#     'badge': {'url': '/globalassets/catalog/beerwulf/beers/awards/bbc2018-silver-medal.png',
#      'alt': 'BBC 2018 Silver',
#      'title': 'BBC 2018 Silver'},
#     'name': None}],
#   'contentReference': '/fr-fr/p/bieres/ninkasi-ambree-.33',
#   'redirectedUrl': None,
#   'details': 'Bière Ambrée | 4,5% | 33 cl',
#   'worksWithLabel': None,
#   'productIcon': None,
#   'searchItemType': 0,
#   'promotedPages': [],
#   'code': 'Ninkasi-Ambree.33_1',
#   'inStock': True,
#   'isComingSoon': False,
#   'isBottleOrCan': True,
#   'inReserveStock': True,
#   'style': 'Bière Ambrée',
#   'alcoholPercentage': 4.5,
#   'volume': 33.0,
#   'displayInformationPrice': {'currency': '€',
#    'price': '2,85 €',
#    'filterPrice': 2.85,
#    'fromPrice': None,
#    'discountPrice': None,
#    'discountPercentage': '0',
#    'valueIndicator': None,
#    'pricePerLiter': '8,64 €',
#    'depositMoney': None,
#    'displayDepositMoneyAndPricePerLiter': False,
#    'hasDiscount': False,
#    'vatPercentage': '20%',
#    'saleType': 'Regular',
#    'preorderAvailability': None},
#   'amountInCart': 0,
#   'isInWishlist': False,
#   'containerType': 'Bottle',
#   'includesFreeItem': False,
#   'freeItemIcon': None,
#   'saleType': None,
#   'sellerId': None,
#   'sellerName': None,
#   'sellerFriendlyUrl': None},
#  {'title': 'Desperados',
#   'description': '',
#   'images': [{'image': '/globalassets/desperados.33_1_2.png',
#     'badge': {'url': '/', 'alt': None, 'title': None},
#     'name': None}],
#   'contentReference': '/fr-fr/p/bieres/desperados.33',
#   'redirectedUrl': None,
#   'details': 'Lager | 5,9% | 33 cl',
#   'worksWithLabel': None,
#   'productIcon': None,
#   'searchItemType': 0,
#   'promotedPages': [],
#   'code': 'Desperados.33_1',
#   'inStock': True,
#   'isComingSoon': False,
#   'isBottleOrCan': True,
#   'inReserveStock': True,
#   'style': 'Lager',
#   'alcoholPercentage': 5.9,
#   'volume': 33.0,
#   'displayInformationPrice': {'currency': '€',
#    'price': '1,99 €',
#    'filterPrice': 1.99,
#    'fromPrice': None,
#    'discountPrice': None,
#    'discountPercentage': '0',
#    'valueIndicator': None,
#    'pricePerLiter': '6,03 €',
#    'depositMoney': None,
#    'displayDepositMoneyAndPricePerLiter': False,
#    'hasDiscount': False,
#    'vatPercentage': '20%',
#    'saleType': 'Regular',
#    'preorderAvailability': None},
#   'amountInCart': 0,
#   'isInWishlist': False,
#   'containerType': 'Bottle',
#   'includesFreeItem': False,
#   'freeItemIcon': None,
#   'saleType': None,
#   'sellerId': None,
#   'sellerName': None,
#   'sellerFriendlyUrl': None},
#  {'title': 'Pietra',
#   'description': '',
#   'images': [{'image': '/globalassets/pietra.33_1_1.png',
#     'badge': {'url': '/globalassets/catalog/beerwulf/beers/awards/wba-fr-winner-2016.jpg',
#      'alt': 'WBA FR Winner 2016',
#      'title': 'WBA FR Winner 2016'},
#     'name': None}],
#   'contentReference': '/fr-fr/p/bieres/pietra.33',
#   'redirectedUrl': None,
#   'details': 'Lager | 6,0% | 33 cl',
#   'worksWithLabel': None,
#   'productIcon': None,
#   'searchItemType': 0,
#   'promotedPages': [],
#   'code': 'Pietra.33_1',
#   'inStock': True,
#   'isComingSoon': False,
#   'isBottleOrCan': True,
#   'inReserveStock': True,
#   'style': 'Lager',
#   'alcoholPercentage': 6.0,
#   'volume': 33.0,
#   'displayInformationPrice': {'currency': '€',
#    'price': '2,69 €',
#    'filterPrice': 2.69,
#    'fromPrice': None,
#    'discountPrice': None,
#    'discountPercentage': '0',
#    'valueIndicator': None,
#    'pricePerLiter': '8,15 €',
#    'depositMoney': None,
#    'displayDepositMoneyAndPricePerLiter': False,
#    'hasDiscount': False,
#    'vatPercentage': '20%',
#    'saleType': 'Regular',
#    'preorderAvailability': None},
#   'amountInCart': 0,
#   'isInWishlist': False,
#   'containerType': 'Bottle',
#   'includesFreeItem': False,
#   'freeItemIcon': None,
#   'saleType': None,
#   'sellerId': None,
#   'sellerName': None,
#   'sellerFriendlyUrl': None}]

# %%
# partie B-1
def extract_beer_infos(url):
    
    #print(soup2)
    beer_infos = {
        'Nom': None,
        'Style': None,
        'Contenu': None,
        'Degré d’alcool': None,
        'Origine': None,
        'Brasseur': None
    }
        
    response = requests.get(url)
    soup2 = BeautifulSoup(response.content)    
    for item in soup2.find_all('td', attrs={'class':"header"}):
        
        if item.text == 'Style':
            beer_infos['Style'] = item.find_next().text
        elif item.text == 'Contenu':
            beer_infos['Contenu'] = int(re.search('[0-9]+', item.find_next().text).group(0))
        elif item.text == "Degré d’alcool":
            beer_infos['Degré d’alcool'] = float(item.find_next().text[:-1].replace(',','.'))
        elif item.text == "Origine":
            beer_infos['Origine'] = re.search('[A-Za-z]+', item.find_next().text).group(0)
        elif item.text == "Brasseur":
            beer_infos['Brasseur'] = re.search('[A-Za-z]+', item.find_next().text).group(0)
        for item in soup2.find_all('h1', attrs={'class':"product-name"}):
            beer_infos['Nom'] = item.text
        
    return beer_infos

# %%
# partie B-2
URL_BEERLIST_FRANCE = "https://www.beerwulf.com/fr-FR/api/search/searchProducts?country=France&container=Bouteille"

def extract_beer_list_infos(url):
    # Collecter les pages de bières à partir du JSON
    beer_pages = []
    page = requests.get(URL_BEERLIST_FRANCE).json()
    for i in range(len(page['items'])):
        beer_pages.append('https://www.beerwulf.com' + page["items"][i]['contentReference'])
    
    # Sequential version (slow):
    beers = []
    for i in range (len(beer_pages)):
        beers.append(extract_beer_infos(beer_pages[i]))
    # Facultatif
    # Parallel version (faster):
    # beers = []
    
    return beers

# %%
import unittest

class Session4Tests(unittest.TestCase):
    def test_01_get_prices_from_url_page2(self):
        prices = get_prices_from_url(URL_PAGE2)
        # We should have found 3 products:
        self.assertIsInstance(prices, dict)
        self.assertEqual(len(prices), 3)
        self.assertIn('Personal', prices)
        self.assertIn('Small Business', prices)
        self.assertIn('Enterprise', prices)
        
        personal = prices['Personal']
        self.assertIn('price', personal)
        self.assertIn('storage', personal)
        self.assertIn('databases', personal)
        self.assertEqual(personal['price'], '$5')
        self.assertEqual(personal['storage'], '1GB')
        self.assertEqual(personal['databases'], 1)
        
    def test_02_get_prices_from_url_page3(self):
        prices = get_prices_from_url(URL_PAGE3)
        self.assertIsInstance(prices, dict)
        self.assertEqual(len(prices), 4)
        self.assertEqual(
            prices['Privilege'],
            {'databases': 100, 'price': '$99', 'storage': '1TB'}
        )
    
    def test_03_extract_beer_list_infos(self):
        infos = extract_beer_list_infos(URL_BEERLIST_FRANCE)
        self.assertIsInstance(infos, list)
        self.assertGreater(len(infos), 1)
        # Contenu = int
        # Degré d’alcool = float
        for beer in infos:
            self.assertIsInstance(beer['Nom'], str)
            self.assertIsInstance(beer['Style'], str)
            self.assertIsInstance(beer['Contenu'], int)
            self.assertIsInstance(beer['Degré d’alcool'], float)
            self.assertEqual(beer['Origine'], "France")
            self.assertIsInstance(beer['Brasseur'], str)

            
def run_tests():
    test_suite = unittest.makeSuite(Session4Tests)
    runner = unittest.TextTestRunner(verbosity=2)
    runner.run(test_suite)

# %%
if __name__ == '__main__':
    run_tests()
# Out:
# test_01_get_prices_from_url_page2 (__main__.Session4Tests) ... ok
# test_02_get_prices_from_url_page3 (__main__.Session4Tests) ... ok
# test_03_extract_beer_list_infos (__main__.Session4Tests) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 1.782s
#
# OK

# %%
from scipy.stats import norm

# %%
norm.ppf(1-0.01/2)
# Out:
# 2.5758293035489004

# %%
2*norm.cdf(-2)
# Out:
# 0.04550026389635839
