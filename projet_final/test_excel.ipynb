# %%
import requests
from urllib import request
from shutil import copyfileobj
import pandas as pd
import urllib3
from bs4 import BeautifulSoup
import numpy as pn
import openpyxl
import re
import datetime
from projet_final_function import *
# Out:
# /Users/dorianfitton/opt/anaconda3/envs/bgd/lib/python3.10/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (5.0.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# /Users/dorianfitton/opt/anaconda3/envs/bgd/lib/python3.10/site-packages/xlwings/pro/utils.py:148: UserWarning: Your license key expires in 26 days.
#   warnings.warn(

# %%
from projet_final_function import *

# %%
file_name = "vendeeglobe_20210204_140000"
path = "/Users/dorianfitton/Documents/Cours_Télécom/Kit BIG DATA/kit_bgd/projet_final/data/"

df = extract_inrace(file_name, path)

df = prep_df(df)
inf_voil = pd.read_csv('/Users/dorianfitton/Documents/Cours_Télécom/Kit BIG DATA/kit_bgd/projet_final/infos_voiliers')

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       1 file_name = "vendeeglobe_20210204_140000"
#       2 path = "/Users/dorianfitton/Documents/Cours_Télécom/Kit BIG DATA/kit_bgd/projet_final/data/"
# ----> 4 df = extract_inrace(file_name, path)
#       6 df = prep_df(df)
#       7 inf_voil = pd.read_csv('/Users/dorianfitton/Documents/Cours_Télécom/Kit BIG DATA/kit_bgd/projet_final/infos_voiliers')
#
# File ~/Documents/Cours_Télécom/Kit BIG DATA/kit_bgd/projet_final/projet_final_function.py:99, in extract_inrace(filename, path)
#      91 def extract_inrace(filename, path):
#      92     header_list_ = ['Rang', 'Nat. / Voile', 'Skipper / Bateau', 'Heure FR', 'Latitude', 'Longitude',
#      93                     'Depuis 30 minutes - Cap', 'Depuis 30 minutes - Vitesse', 'Depuis 30 minutes - VMG',
# ...

# %%
inf_voil
# Out:
#     Unnamed: 0               Skipper Numéro de voile  \
# 0            0        Fabrice Amedeo          FRA 56
# 1            1      Romain Attanasio          FRA 49
# 2            2        Alexia Barrier           FRA72
# 3            3      Yannick Bestaven              17
# 4            4         Jeremie Beyou              08
# 5            5     Arnaud Boissieres          FRA 14
# 6            6          Louis Burton              18
# 7            7           Didac Costa          ESP 33
# 8            8         Manuel Cousin          FRA 71
# 9            9       Clarisse Cremer           FRA30
# 10          10         Charlie Dalin          FRA 79
# 11          11            Sam Davies          FRA109
# 12          12   Sebastien Destremau              69
# 13          13      Benjamin Dutreux           FRA09
# 14          14       Kevin Escoffier          FRA 85
# 15          15        Clement Giraud           FRA83
# 16          16              Pip Hare           GBR77
# ...

# %%
pd.read_excel("/Users/dorianfitton/Documents/Cours_Télécom/Kit BIG DATA/kit_bgd/projet_final/data/vendeeglobe_20210204_140000.xlsx")
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                                                NaN
# 1          NaN     Classement du jeudi 04 février 2021 à 15h00 FR
# 2          NaN                                         Rang\nRank
# 3          NaN                                                NaN
# 4          NaN                                             1\nARV
# 5          NaN                                             2\nARV
# 6          NaN                                             3\nARV
# 7          NaN                                             4\nARV
# 8          NaN                                             5\nARV
# 9          NaN                                             6\nARV
# 10         NaN                                             7\nARV
# 11         NaN                                             8\nARV
# 12         NaN                                             9\nARV
# ...

# %%
with xw.Book("/Users/dorianfitton/Documents/Cours_Télécom/Kit BIG DATA/kit_bgd/projet_final/data/vendeeglobe_20210204_140000.xlsx", mode="r") as book:
    sheet1 = book.sheets[0]
    data = sheet1.cells.value
    df = pd.DataFrame(data).drop(0).replace('\r', '', regex=True).reset_index().drop('index', axis=1)

# %%
df
# Out:
#       0                                                  1   \
# 0   None                                               None
# 1   None     Classement du jeudi 04 février 2021 à 15h00 FR
# 2   None                                         Rang\nRank
# 3   None                                               None
# 4   None                                             1\nARV
# 5   None                                             2\nARV
# 6   None                                             3\nARV
# 7   None                                             4\nARV
# 8   None                                             5\nARV
# 9   None                                             6\nARV
# 10  None                                             7\nARV
# 11  None                                             8\nARV
# 12  None                                             9\nARV
# 13  None                                            10\nARV
# 14  None                                            11\nARV
# ...

# %%
pd.merge(df, inf_voil, on = 'Skipper')
# Out:
#     Rang  Heure FR   Latitude  Longitude  Depuis 30 minutes - Cap  \
# 0     13  14:30 FR  45.190000  15.159444                       66
# 1     14  14:30 FR  43.929167  16.585278                       57
# 2     15  14:30 FR  36.014444  43.794722                      325
# 3     16  14:30 FR  35.574167  44.269444                       25
# 4     18  14:30 FR  35.883611  45.123333                       34
# 5     19  14:30 FR  29.113333  42.034722                      350
# 6     20  14:30 FR  32.966389  45.825833                       10
# 7     21  14:30 FR   8.321667  33.650278                      337
# 8     22  14:30 FR   8.957500  35.157778                      346
# 9     23  14:30 FR   5.660000  31.048056                      322
# 10    24  14:30 FR  26.249167  31.268333                      345
# 11    25  14:30 FR  28.858056  27.200833                       89
#
#     Depuis 30 minutes - Vitesse  Depuis 30 minutes - VMG  \
# ...
